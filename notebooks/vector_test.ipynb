# %%
import sys
sys.path.append(r"C:\financial_news_intel")

import importlib
import src.vector.vector_store
importlib.reload(src.vector.vector_store)

from src.vector.vector_store import VectorStore
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       2 sys.path.append(r"C:\financial_news_intel")
#       4 from src.vector.vector_store import VectorStore
# ----> 6 store = VectorStore()
#       8 store.add_document("doc1", "RBI raises repo rate by 25 bps", {"source": "test"})
#      10 res = store.query("central bank increased interest rates", top_k=1)
#
# File C:\financial_news_intel\src\vector\vector_store.py:15, in VectorStore.__init__(self)
#      12 def __init__(self):
#      13     self.logger = get_logger("VectorStore")
# ---> 15     self.client = chromadb.Client(
#      16         Settings(
#      17             chroma_db_impl="duckdb+parquet",
#      18             persist_directory=Config.CHROMA_DIR
#      19         )
#      20     )
#      22     self.collection = self.client.get_or_create_collection(
#      23         name="news_articles",
# ...

# %%
import chromadb
chromadb.__version__
# Out:
# '1.3.5'
